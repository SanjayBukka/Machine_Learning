# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("insurance_data.csv")
df.head(5)
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df.age,df.bought_insurance,marker="+",color="red")

# %%
df.shape
# Out:
# (27, 2)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(df[["age"]],df.bought_insurance,test_size=0.2)

# %%
X_test
# Out:
#     age
# 6    55
# 26   23
# 21   26
# 17   58
# 18   19
# 11   28

# %%
len(X_test)
# Out:
# 6

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([1, 0, 0, 1, 0, 0])

# %%
model.score(X_test,y_test)
# Out:
# 0.8333333333333334

# %%
model.predict_proba(X_test)
# Out:
# array([[0.04399949, 0.95600051],
#        [0.8626268 , 0.1373732 ],
#        [0.79841524, 0.20158476],
#        [0.02821057, 0.97178943],
#        [0.92069032, 0.07930968],
#        [0.74444047, 0.25555953]])

# %%
model.predict([[67]])
# Out:
# c:\Users\Sanjay\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])
