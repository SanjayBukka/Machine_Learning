# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
from sklearn import linear_model

# %%
df =pd.read_csv("prediction.csv")
df
# Out:
#     area        prices
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06

# %%
# %matplotlib inline
plt.xlabel('area sqft')
plt.ylabel('price us$')
plt.scatter(df.area,df.prices,color='black',marker='+')

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['area']],df.prices)
# Out:
# LinearRegression()

# %%
reg.predict

# %%
reg.predict([[3300]])
# Out:
# c:\Users\Sanjay\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# np.float64(180616.43835616473)

# %%
#y=mx+c
price_1=135.78767123*3300+180616.43835616473
price_1
# Out:
# 628715.7534151648

# %%
# %matplotlib inline
plt.scatter(df.area,df.prices,color='red',marker='+')
plt.plot(df.area,reg.predict(df[['area']]),color='blue')
